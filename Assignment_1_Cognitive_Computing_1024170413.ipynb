# %% [markdown]
# # Assignment 1
#
# Aadish Jain
#
# Roll No: 1024170413
#
# Batch: 3Q33
#
# Cognitive Computing Assignment Submission

# %% [markdown]
# ## Assignment 1.1
# **Question:** WAP to print your name three times

# %%
for i in range(3):
    print("Aadish Jain")

# %% [markdown]
# ## Assignment 2.1
# **Question:** WAP to add three numbers and print the result.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print("Sum =", a + b + c)

# %% [markdown]
# ## Assignment 2.2
# **Question:** WAP to concatenate three strings and print the result.

# %%
s1 = input("Enter first string: ")
s2 = input("Enter second string: ")
s3 = input("Enter third string: ")
print("Concatenated String:", s1 + s2 + s3)

# %% [markdown]
# ## Assignment 4.1
# **Question:** WAP to print the table of 7 and 9.

# %%
for n in [7, 9]:
    print(f"Table of {n}")
    for i in range(1, 11):
        print(f"{n} x {i} = {n*i}")
    print()

# %% [markdown]
# ## Assignment 4.2
# **Question:** WAP to print the table of n given by the user.

# %%
n = int(input("Enter a number: "))
for i in range(1, 11):
    print(f"{n} x {i} = {n*i}")

# %% [markdown]
# ## Assignment 4.3
# **Question:** WAP to add all numbers from 1 to n.

# %%
n = int(input("Enter n: "))
total = 0
for i in range(1, n + 1):
    total += i
print("Sum =", total)

# %% [markdown]
# ## Assignment 5.1
# **Question:** WAP to find maximum among three numbers.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
print("Maximum =", max(a, b, c))

# %% [markdown]
# ## Assignment 5.2
# **Question:** WAP to add all numbers divisible by 7 and 9 from 1 to n.

# %%
n = int(input("Enter n: "))
total = 0
for i in range(1, n + 1):
    if i % 7 == 0 and i % 9 == 0:
        total += i
print("Sum =", total)

# %% [markdown]
# ## Assignment 5.3
# **Question:** WAP to add all prime numbers from 1 to n.

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5)+1):
        if num % i == 0:
            return False
    return True

n = int(input("Enter n: "))
total = 0
for i in range(2, n+1):
    if is_prime(i):
        total += i
print("Sum =", total)

# %% [markdown]
# ## Assignment 6.1
# **Question:** WAP using a function to add all odd numbers from 1 to n.

# %%
def odd_sum(n):
    total = 0
    for i in range(1, n+1, 2):
        total += i
    return total

n = int(input("Enter n: "))
print("Sum =", odd_sum(n))

# %% [markdown]
# ## Assignment 6.2
# **Question:** WAP using a function to add all prime numbers from 1 to n.

# %%
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num**0.5)+1):
        if num % i == 0:
            return False
    return True

def prime_sum(n):
    total = 0
    for i in range(2, n+1):
        if is_prime(i):
            total += i
    return total

n = int(input("Enter n: "))
print("Sum =", prime_sum(n))
